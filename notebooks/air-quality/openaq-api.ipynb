# %% [markdown]
# # OpenAQ API Data Query
#
# [OpenAQ](https://openaq.org/) aggregates air qualty datasets worldwide, into a common data object.
#
# OpenAQ provides an [API](https://docs.openaq.org/docs/introduction) to access these datasets, provided the user submit a query.
#
# While python packages, such as [py-openaq](https://github.com/dhhagan/py-openaq) exist to use this API, this notebook will query the API directly.

# %% [markdown]
# ## API Query Creation
#
# This query was created with the [API Reference](https://docs.openaq.org/reference/measurements_get_v2_measurements_get)
#
# There is also [direct file access](https://docs.openaq.org/docs/accessing-openaq-archive-data) in an S3 bucket, but locations of observations must be known

# %%
import requests

# %% [markdown]
# ### Bounding Box
#
# Initial attempts at accessing the API were to pass a [bounding box](http://bboxfinder.com/#0.000000,0.000000,0.000000,0.000000) for the Chicago region

# %%
chicago_bbox = [-88.885961, 41.274839, -87.117162, 42.477288]

# %% [markdown]
# ###  Location Name
#
# Location identifers follow EPA guidelines, so Chicago metro is:
# `Chicago-Naperville-Joliet`

# %%
url = "https://api.openaq.org/v2/locations?limit=1000&page=1&offset=0&sort=desc&parameter_id=2&radius=1000&country=US&city=Chicago-Naperville-Joliet&order_by=lastUpdated&dump_raw=false"
headers = {"accept": "application/json"}
response = requests.get(url, headers=headers)

# %%
url = "https://api.openaq.org/v2/locations?limit=1000&page=1&offset=0&sort=desc&parameter_id=2&radius=1000&country=US&city=Chicago-Naperville-Joliet&order_by=lastUpdated&dump_raw=false&provider=purpleair"
headers = {"accept": "application/json"}
response = requests.get(url, headers=headers)

# %%
response
# Out:
# <Response [200]>

# %%
response.text
# Out:
# '{"meta":{"name":"openaq-api","license":"","website":"/","page":1,"limit":1000,"found":18},"results":[{"id":2047319,"city":"Chicago-Naperville-Joliet","name":"McCook","entity":null,"country":"US","sources":null,"isMobile":false,"isAnalysis":null,"parameters":[{"id":2,"unit":"µg/m³","count":1432,"average":6.8,"lastValue":7.3,"parameter":"pm25","displayName":"pm25 µg/m³","lastUpdated":"2024-03-11T18:00:00+00:00","parameterId":2,"firstUpdated":"2024-01-02T16:00:00+00:00","manufacturers":null}],"sensorType":null,"coordinates":{"latitude":41.80117,"longitude":-87.83194},"lastUpdated":"2024-03-11T18:00:00+00:00","firstUpdated":"2024-01-02T16:00:00+00:00","measurements":1432,"bounds":[-87.83194,41.80117,-87.83194,41.80117],"manufacturers":[{"modelName":"Government Monitor","manufacturerName":"Unknown Governmental Organization"}]},{"id":223,"city":"Chicago-Naperville-Joliet","name":"Gary-IITRI","entity":null,"country":"US","sources":null,"isMobile":false,"isAnalysis":null,"parameters":[{"id":11,"unit":"µg/m³","count":30258,"average":0.6917327648886192,"lastValue":0.18,"parameter":"bc","displayName":"bc µg/m³","lastUpdated":"2021-01-02T00:00:00+00:00","parameterId":11,"firstUpdated":"2016-03-06T19:00:00+00:00","manufacturers":null},{"id":9,"unit":"ppm","count":49791,"average":0.0007170649379680644,"lastValue":0.0001,"parameter":"so2","displayName":"so2 ppm","lastUpdated":"2024-03-11T18:00:00+00:00","parameterId":9,"firstUpdated":"2016-03-06T19:00:00+00:00","manufacturers":null},{"id":7,"unit":"ppm","count":46393,"average":0.008949742701870322,"lastValue":0.0007,"parameter":"no2","displayName":"no2 ppm","lastUpdated":"2024-03-11T18:00:00+00:00","parameterId":7,"firstUpdated":"2016-03-06T19:00:00+00:00","manufacturers":null},{"id":2,"unit":"µg/m³","count":9572,"average":8.862299537917904,"lastValue":0.5,"parameter":"pm25","displayName":"pm25 µg/m³","lastUpdated":"2024-03-10T19:00:00+00:00","parameterId":2,"firstUpdated":"2016-03-13T05:00:00+00:00","manufacturers":null},{"id":10,"unit":"ppm","count":44841,"average":0.027885810454396066,"lastValue":0.041,"parameter":"o3","displayName":"o3 ppm","lastUpdated":"2024-03-11T18:00:00+00:00","parameterId":10,"firstUpdated":"2016-04-01T07:00:00+00:00","manufacturers":null},{"id":1,"unit":"µg/m³","count":51468,"average":19.168185735832825,"lastValue":42.0,"parameter":"pm10","displayName":"pm10 µg/m³","lastUpdated":"2024-03-11T18:00:00+00:00","parameterId":1,"firstUpdated":"2016-03-06T19:00:00+00:00","manufacturers":null}],"sensorType":null,"coordinates":{"latitude":41.606563,"longitude":-87.305015},"lastUpdated":"2024-03-11T18:00:00+00:00","firstUpdated":"2016-03-06T19:00:00+00:00","measurements":232323,"bounds":[-87.305015,41.606563,-87.305015,41.606563],"manufacturers":[{"modelName":"Government Monitor","manufacturerName":"Unknown Governmental Organization"}]},{"id":424,"city":"Chicago-Naperville-Joliet","name":"CHI_COM","entity":null,"country":"US","sources":null,"isMobile":false,"isAnalysis":null,"parameters":[{"id":10,"unit":"ppm","count":38446,"average":0.027506245099136333,"lastValue":0.041,"parameter":"o3","displayName":"o3 ppm","lastUpdated":"2024-03-11T18:00:00+00:00","parameterId":10,"firstUpdated":"2016-03-06T19:00:00+00:00","manufacturers":null},{"id":2,"unit":"µg/m³","count":49120,"average":9.071560256381174,"lastValue":5.3,"parameter":"pm25","displayName":"pm25 µg/m³","lastUpdated":"2024-03-11T18:00:00+00:00","parameterId":2,"firstUpdated":"2016-03-06T19:00:00+00:00","manufacturers":null}],"sensorType":null,"coordinates":{"latitude":41.7547,"longitude":-87.7136},"lastUpdated":"2024-03-11T18:00:00+00:00","firstUpdated":"2016-03-06T19:00:00+00:00","measurements":87566,"bounds":[-87.7136,41.7547,-87.7136,41.7547],"manufacturers":[{"modelName":"Government Monitor","manufacturerName":"Unknown Governmental Organization"}]},{"id":1153,"city":"Chicago-Naperville-Joliet","name":"ALSIP","entity":null,"country":"US","sources":null,"isMobile":false,"isAnalysis":null,"parameters":[{"id":10,"unit" ...

# %%
data = response.json()

# %%
data
# Out:
# {'meta': {'name': 'openaq-api',
#   'license': '',
#   'website': '/',
#   'page': 1,
#   'limit': 1000,
#   'found': 18},
#  'results': [{'id': 2047319,
#    'city': 'Chicago-Naperville-Joliet',
#    'name': 'McCook',
#    'entity': None,
#    'country': 'US',
#    'sources': None,
#    'isMobile': False,
#    'isAnalysis': None,
#    'parameters': [{'id': 2,
#      'unit': 'µg/m³',
#      'count': 1432,
#      'average': 6.8,
#      'lastValue': 7.3,
#      'parameter': 'pm25',
#      'displayName': 'pm25 µg/m³',
#      'lastUpdated': '2024-03-11T18:00:00+00:00',
#      'parameterId': 2,
#      'firstUpdated': '2024-01-02T16:00:00+00:00',
#      'manufacturers': None}],
#    'sensorType': None,
#    'coordinates': {'latitude': 41.80117, 'longitude': -87.83194},
#    'lastUpdated': '2024-03-11T18:00:00+00:00',
#    'firstUpdated': '2024-01-02T16:00:00+00:00',
#    'measurements': 1432,
#    'bounds': [-87.83194, 41.80117, -87.83194, 41.80117],
#    'manufacturers': [{'modelName': 'Government Monitor',
#      'manufacturerName': 'Unknown Governmental Organization'}]},
#   {'id': 223,
#    'city': 'Chicago-Naperville-Joliet',
#    'name': 'Gary-IITRI',
#    'entity': None,
#    'country': 'US',
#    'sources': None,
#    'isMobile': False,
#    'isAnalysis': None,
#    'parameters': [{'id': 11,
#      'unit': 'µg/m³',
#      'count': 30258,
#      'average': 0.6917327648886192,
#      'lastValue': 0.18,
#      'parameter': 'bc',
#      'displayName': 'bc µg/m³',
#      'lastUpdated': '2021-01-02T00:00:00+00:00',
#      'parameterId': 11,
#      'firstUpdated': '2016-03-06T19:00:00+00:00',
#      'manufacturers': None},
#     {'id': 9,
#      'unit': 'ppm',
#      'count': 49791,
#      'average': 0.0007170649379680644,
#      'lastValue': 0.0001,
#      'parameter': 'so2',
#      'displayName': 'so2 ppm',
#      'lastUpdated': '2024-03-11T18:00:00+00:00',
#      'parameterId': 9,
#      'firstUpdated': '2016-03-06T19:00:00+00:00',
#      'manufacturers': None},
#     {'id': 7,
#      'unit': 'ppm',
#      'count': 46393,
#      'average': 0.008949742701870322,
#      'lastValue': 0.0007,
#      'parameter': 'no2',
#      'displayName': 'no2 ppm',
#      'lastUpdated': '2024-03-11T18:00:00+00:00',
#      'parameterId': 7,
#      'firstUpdated': '2016-03-06T19:00:00+00:00',
#      'manufacturers': None},
#     {'id': 2,
#      'unit': 'µg/m³',
#      'count': 9572,
#      'average': 8.862299537917904,
#      'lastValue': 0.5,
#      'parameter': 'pm25',
#      'displayName': 'pm25 µg/m³',
#      'lastUpdated': '2024-03-10T19:00:00+00:00',
#      'parameterId': 2,
#      'firstUpdated': '2016-03-13T05:00:00+00:00',
#      'manufacturers': None},
#     {'id': 10,
#      'unit': 'ppm',
#      'count': 44841,
#      'average': 0.027885810454396066,
#      'lastValue': 0.041,
#      'parameter': 'o3',
#      'displayName': 'o3 ppm',
#      'lastUpdated': '2024-03-11T18:00:00+00:00',
#      'parameterId': 10,
#      'firstUpdated': '2016-04-01T07:00:00+00:00',
#      'manufacturers': None},
#     {'id': 1,
#      'unit': 'µg/m³',
#      'count': 51468,
#      'average': 19.168185735832825,
#      'lastValue': 42.0,
#      'parameter': 'pm10',
#      'displayName': 'pm10 µg/m³',
#      'lastUpdated': '2024-03-11T18:00:00+00:00',
#      'parameterId': 1,
#      'firstUpdated': '2016-03-06T19:00:00+00:00',
#      'manufacturers': None}],
#    'sensorType': None,
#    'coordinates': {'latitude': 41.606563, 'longitude': -87.305015},
#    'lastUpdated': '2024-03-11T18:00:00+00:00',
#    'firstUpdated': '2016-03-06T19:00:00+00:00',
#    'measurements': 232323,
#    'bounds': [-87.305015, 41.606563, -87.305015, 41.606563],
#    'manufacturers': [{'modelName': 'Government Monitor',
#      'manufacturerName': 'Unknown Governmental Organization'}]},
#   {'id': 424,
#    'city': 'Chicago-Naperville-Joliet',
#    'name': 'CHI_COM',
#    'entity': None,
#    'country': 'US',
#    'sources': None,
#    'isMobile': False,
#    'isAnalysis': None,
#    'parameters': [{'id': 10,
#      'unit': 'ppm',
#      'count': 38446,
#      'average': 0.027506245099136333,
#      'lastValue': 0.041,
#      'parameter': 'o3',
#      'displayName': 'o3 ppm',
#      'lastUpdated': '2024-03-11T18:00:00+00:00',
#      'parameterId': 10,
#      'firstUpdated': '2016-03-06T19:00:00+00:00',
#      'manufacturers': None},
#     {'id': 2,
#      'unit': 'µg/m³',
#      'count': 49120,
#      'average': 9.071560256381174,
#      'lastValue': 5.3,
#      'parameter': 'pm25',
#      'displayName': 'pm25 µg/m³',
#      'lastUpdated': '2024-03-11T18:00:00+00:00',
#      'parameterId': 2,
#      'firstUpdated': '2016-03-06T19:00:00+00:00',
#      'manufacturers': None}],
#    'sensorType': None,
#    'coordinates': {'latitude': 41.7547, 'longitude': -87.7136},
#    'lastUpdated': '2024-03-11T18:00:00+00:00',
#    'firstUpdated': '2016-03-06T19:00:00+00:00',
#    'measurements': 87566,
#    'bounds': [-87.7136, 41.7547, -87.7136, 41.7547],
#    'manufacturers': [{'modelName': 'Government Monitor',
#      'manufacturerName': 'Unknown Governmental Organization'}]},
#   {'id': 1153,
#    'city': 'Chicago-Naperville-Joliet',
#    'name': 'ALSIP',
#    'entity': None,
#    'country': 'US',
#    'sources': None,
#    'isMobile': False,
#    'isAnalysis': None,
#    'parameters': [{'id': 10,
#      'unit': 'ppm',
#      'count': 40762,
#      'average': 0.028271936052167115,
#      'lastValue': 0.04,
#      'parameter': 'o3',
#      'displayName': 'o3 ppm',
#      'lastUpdated': '2024-03-11T18:00:00+00:00',
#      'parameterId': 10,
#      'firstUpdated': '2016-03-06T19:00:00+00:00',
#      'manufacturers': None},
#     {'id': 2,
#      'unit': 'µg/m³',
#      'count': 46839,
#      'average': 9.117925675192474,
#      'lastValue': 7.0,
#      'parameter': 'pm25',
#      'displayName': 'pm25 µg/m³',
#      'lastUpdated': '2024-03-11T18:00:00+00:00',
#      'parameterId': 2,
#      'firstUpdated': '2016-03-06T19:00:00+00:00',
#      'manufacturers': None}],
#    'sensorType': None,
#    'coordinates': {'latitude': 41.6708, 'longitude': -87.7325},
#    'lastUpdated': '2024-03-11T18:00:00+00:00',
#    'firstUpdated': '2016-03-06T19:00:00+00:00',
#    'measurements': 87601,
#    'bounds': [-87.7325, 41.6708, -87.7325, 41.6708],
#    'manufacturers': [{'modelName': 'Government Monitor',
#      'manufacturerName': 'Unknown Governmental Organization'}]},
#   {'id': 1414,
#    'city': 'Chicago-Naperville-Joliet',
#    'name': 'BRAIDWD',
#    'entity': None,
#    'country': 'US',
#    'sources': None,
#    'isMobile': False,
#    'isAnalysis': None,
#    'parameters': [{'id': 10,
#      'unit': 'ppm',
#      'count': 42305,
#      'average': 0.030714307504575218,
#      'lastValue': 0.042,
#      'parameter': 'o3',
#      'displayName': 'o3 ppm',
#      'lastUpdated': '2024-03-11T18:00:00+00:00',
#      'parameterId': 10,
#      'firstUpdated': '2016-03-06T19:00:00+00:00',
#      'manufacturers': None},
#     {'id': 2,
#      'unit': 'µg/m³',
#      'count': 50400,
#      'average': 8.516323861873293,
#      'lastValue': 5.3,
#      'parameter': 'pm25',
#      'displayName': 'pm25 µg/m³',
#      'lastUpdated': '2024-03-11T18:00:00+00:00',
#      'parameterId': 2,
#      'firstUpdated': '2016-03-06T19:00:00+00:00',
#      'manufacturers': None}],
#    'sensorType': None,
#    'coordinates': {'latitude': 41.2222, 'longitude': -88.1906},
#    'lastUpdated': '2024-03-11T18:00:00+00:00',
#    'firstUpdated': '2016-03-06T19:00:00+00:00',
#    'measurements': 92705,
#    'bounds': [-88.1906, 41.2222, -88.1906, 41.2222],
#    'manufacturers': [{'modelName': 'Government Monitor',
#      'manufacturerName': 'Unknown Governmental Organization'}]},
#   {'id': 1621,
#    'city': 'Chicago-Naperville-Joliet',
#    'name': 'CARY',
#    'entity': None,
#    'country': 'US',
#    'sources': None,
#    'isMobile': False,
#    'isAnalysis': None,
#    'parameters': [{'id': 2,
#      'unit': 'µg/m³',
#      'count': 49927,
#      'average': 8.747162874117269,
#      'lastValue': 5.3,
#      'parameter': 'pm25',
#      'displayName': 'pm25 µg/m³',
#      'lastUpdated': '2024-03-11T18:00:00+00:00',
#      'parameterId': 2,
#      'firstUpdated': '2016-03-06T19:00:00+00:00',
#      'manufacturers': None},
#     {'id': 10,
#      'unit': 'ppm',
#      'count': 40094,
#      'average': 0.031798923573734594,
#      'lastValue': 0.04,
#      'parameter': 'o3',
#      'displayName': 'o3 ppm',
#      'lastUpdated': '2024-03-11T18:00:00+00:00',
#      'parameterId': 10,
#      'firstUpdated': '2016-03-06T19:00:00+00:00',
#      'manufacturers': None}],
#    'sensorType': None,
#    'coordinates': {'latitude': 42.2211, 'longitude': -88.2411},
#    'lastUpdated': '2024-03-11T18:00:00+00:00',
#    'firstUpdated': '2016-03-06T19:00:00+00:00',
#    'measurements': 90021,
#    'bounds': [-88.2411, 42.2211, -88.2411, 42.2211],
#    'manufacturers': [{'modelName': 'Government Monitor',
#      'manufacturerName': 'Unknown Governmental Organization'}]},
#   {'id': 1656,
#    'city': 'Chicago-Naperville-Joliet',
#    'name': 'CHIWAUKEE',
#    'entity': None,
#    'country': 'US',
#    'sources': None,
#    'isMobile': False,
#    'isAnalysis': None,
#    'parameters': [{'id': 10,
#      'unit': 'ppm',
#      'count': 30835,
#      'average': 0.03631169244928967,
#      'lastValue': 0.044,
#      'parameter': 'o3',
#      'displayName': 'o3 ppm',
#      'lastUpdated': '2024-03-11T18:00:00+00:00',
#      'parameterId': 10,
#      'firstUpdated': '2016-04-01T15:00:00+00:00',
#      'manufacturers': None},
#     {'id': 2,
#      'unit': 'µg/m³',
#      'count': 46492,
#      'average': 7.234893492992632,
#      'lastValue': 4.8,
#      'parameter': 'pm25',
#      'displayName': 'pm25 µg/m³',
#      'lastUpdated': '2024-03-11T18:00:00+00:00',
#      'parameterId': 2,
#      'firstUpdated': '2016-03-06T19:00:00+00:00',
#      'manufacturers': None}],
#    'sensorType': None,
#    'coordinates': {'latitude': 42.5047, 'longitude': -87.8111},
#    'lastUpdated': '2024-03-11T18:00:00+00:00',
#    'firstUpdated': '2016-03-06T19:00:00+00:00',
#    'measurements': 77327,
#    'bounds': [-87.8111, 42.5047, -87.8111, 42.5047],
#    'manufacturers': [{'modelName': 'Government Monitor',
#      'manufacturerName': 'Unknown Governmental Organization'}]},
#   {'id': 1657,
#    'city': 'Chicago-Naperville-Joliet',
#    'name': 'CHI_SP',
#    'entity': None,
#    'country': 'US',
#    'sources': None,
#    'isMobile': False,
#    'isAnalysis': None,
#    'parameters': [{'id': 2,
#      'unit': 'µg/m³',
#      'count': 32266,
#      'average': 9.100754981033411,
#      'lastValue': 4.4,
#      'parameter': 'pm25',
#      'displayName': 'pm25 µg/m³',
#      'lastUpdated': '2024-03-11T18:00:00+00:00',
#      'parameterId': 2,
#      'firstUpdated': '2016-03-11T15:00:00+00:00',
#      'manufacturers': None}],
#    'sensorType': None,
#    'coordinates': {'latitude': 41.9136, 'longitude': -87.7239},
#    'lastUpdated': '2024-03-11T18:00:00+00:00',
#    'firstUpdated': '2016-03-11T15:00:00+00:00',
#    'measurements': 32266,
#    'bounds': [-87.7239, 41.9136, -87.7239, 41.9136],
#    'manufacturers': [{'modelName': 'Government Monitor',
#      'manufacturerName': 'Unknown Governmental Organization'}]},
#   {'id': 1856,
#    'city': 'Chicago-Naperville-Joliet',
#    'name': 'Cicero Liberty',
#    'entity': None,
#    'country': 'US',
#    'sources': None,
#    'isMobile': False,
#    'isAnalysis': None,
#    'parameters': [{'id': 2,
#      'unit': 'µg/m³',
#      'count': 45473,
#      'average': 9.149802410590773,
#      'lastValue': 8.0,
#      'parameter': 'pm25',
#      'displayName': 'pm25 µg/m³',
#      'lastUpdated': '2024-03-11T18:00:00+00:00',
#      'parameterId': 2,
#      'firstUpdated': '2016-03-06T19:00:00+00:00',
#      'manufacturers': None}],
#    'sensorType': None,
#    'coordinates': {'latitude': 41.864329, 'longitude': -87.748826},
#    'lastUpdated': '2024-03-11T18:00:00+00:00',
#    'firstUpdated': '2016-03-06T19:00:00+00:00',
#    'measurements': 45473,
#    'bounds': [-87.748826, 41.864329, -87.748826, 41.864329],
#    'manufacturers': [{'modelName': 'Government Monitor',
#      'manufacturerName': 'Unknown Governmental Organization'}]},
#   {'id': 1962,
#    'city': 'Chicago-Naperville-Joliet',
#    'name': 'NORTHBRK',
#    'entity': None,
#    'country': 'US',
#    'sources': None,
#    'isMobile': False,
#    'isAnalysis': None,
#    'parameters': [{'id': 2,
#      'unit': 'µg/m³',
#      'count': 45078,
#      'average': 8.342141367439746,
#      'lastValue': 5.9,
#      'parameter': 'pm25',
#      'displayName': 'pm25 µg/m³',
#      'lastUpdated': '2024-03-11T18:00:00+00:00',
#      'parameterId': 2,
#      'firstUpdated': '2016-07-28T13:00:00+00:00',
#      'manufacturers': None},
#     {'id': 10,
#      'unit': 'ppm',
#      'count': 51776,
#      'average': 0.030157617799921627,
#      'lastValue': 0.041,
#      'parameter': 'o3',
#      'displayName': 'o3 ppm',
#      'lastUpdated': '2024-03-11T18:00:00+00:00',
#      'parameterId': 10,
#      'firstUpdated': '2016-03-06T19:00:00+00:00',
#      'manufacturers': None}],
#    'sensorType': None,
#    'coordinates': {'latitude': 42.1406, 'longitude': -87.7994},
#    'lastUpdated': '2024-03-11T18:00:00+00:00',
#    'firstUpdated': '2016-03-06T19:00:00+00:00',
#    'measurements': 96854,
#    'bounds': [-87.7994, 42.1406, -87.7994, 42.1406],
#    'manufacturers': [{'modelName': 'Government Monitor',
#      'manufacturerName': 'Unknown Governmental Organization'}]},
#   {'id': 2085,
#    'city': 'Chicago-Naperville-Joliet',
#    'name': 'SCHILPRK',
#    'entity': None,
#    'country': 'US',
#    'sources': None,
#    'isMobile': False,
#    'isAnalysis': None,
#    'parameters': [{'id': 2,
#      'unit': 'µg/m³',
#      'count': 8441,
#      'average': 10.741591544917624,
#      'lastValue': 6.9,
#      'parameter': 'pm25',
#      'displayName': 'pm25 µg/m³',
#      'lastUpdated': '2024-03-11T18:00:00+00:00',
#      'parameterId': 2,
#      'firstUpdated': '2022-11-15T14:00:00+00:00',
#      'manufacturers': None},
#     {'id': 10,
#      'unit': 'ppm',
#      'count': 42952,
#      'average': 0.024365116513160392,
#      'lastValue': 0.04,
#      'parameter': 'o3',
#      'displayName': 'o3 ppm',
#      'lastUpdated': '2024-03-11T18:00:00+00:00',
#      'parameterId': 10,
#      'firstUpdated': '2016-03-06T19:00:00+00:00',
#      'manufacturers': None}],
#    'sensorType': None,
#    'coordinates': {'latitude': 41.965, 'longitude': -87.8761},
#    'lastUpdated': '2024-03-11T18:00:00+00:00',
#    'firstUpdated': '2016-03-06T19:00:00+00:00',
#    'measurements': 51393,
#    'bounds': [-87.8761, 41.965, -87.8761, 41.965],
#    'manufacturers': [{'modelName': 'Government Monitor',
#      'manufacturerName': 'Unknown Governmental Organization'}]},
#   {'id': 2112,
#    'city': 'Chicago-Naperville-Joliet',
#    'name': 'DESPLNS',
#    'entity': None,
#    'country': 'US',
#    'sources': None,
#    'isMobile': False,
#    'isAnalysis': None,
#    'parameters': [{'id': 2,
#      'unit': 'µg/m³',
#      'count': 41277,
#      'average': 9.523231203944839,
#      'lastValue': 5.7,
#      'parameter': 'pm25',
#      'displayName': 'pm25 µg/m³',
#      'lastUpdated': '2024-03-11T18:00:00+00:00',
#      'parameterId': 2,
#      'firstUpdated': '2016-12-19T14:00:00+00:00',
#      'manufacturers': None},
#     {'id': 10,
#      'unit': 'ppm',
#      'count': 36435,
#      'average': 0.030804829157174654,
#      'lastValue': 0.041,
#      'parameter': 'o3',
#      'displayName': 'o3 ppm',
#      'lastUpdated': '2024-03-11T18:00:00+00:00',
#      'parameterId': 10,
#      'firstUpdated': '2016-03-31T15:00:00+00:00',
#      'manufacturers': None}],
#    'sensorType': None,
#    'coordinates': {'latitude': 42.0603, 'longitude': -87.8631},
#    'lastUpdated': '2024-03-11T18:00:00+00:00',
#    'firstUpdated': '2016-03-31T15:00:00+00:00',
#    'measurements': 77712,
#    'bounds': [-87.8631, 42.0603, -87.8631, 42.0603],
#    'manufacturers': [{'modelName': 'Government Monitor',
#      'manufacturerName': 'Unknown Governmental Organization'}]},
#   {'id': 7405,
#    'city': 'Chicago-Naperville-Joliet',
#    'name': 'Hammond-167th St',
#    'entity': None,
#    'country': 'US',
#    'sources': None,
#    'isMobile': False,
#    'isAnalysis': None,
#    'parameters': [{'id': 2,
#      'unit': 'µg/m³',
#      'count': 30271,
#      'average': 9.516142416818145,
#      'lastValue': 4.7,
#      'parameter': 'pm25',
#      'displayName': 'pm25 µg/m³',
#      'lastUpdated': '2024-03-11T18:00:00+00:00',
#      'parameterId': 2,
#      'firstUpdated': '2019-08-16T13:00:00+00:00',
#      'manufacturers': None}],
#    'sensorType': None,
#    'coordinates': {'latitude': 41.594427, 'longitude': -87.495044},
#    'lastUpdated': '2024-03-11T18:00:00+00:00',
#    'firstUpdated': '2019-08-16T13:00:00+00:00',
#    'measurements': 30271,
#    'bounds': [-87.495044, 41.594427, -87.495044, 41.594427],
#    'manufacturers': [{'modelName': 'Government Monitor',
#      'manufacturerName': 'Unknown Governmental Organization'}]},
#   {'id': 8555,
#    'city': 'Chicago-Naperville-Joliet',
#    'name': 'Naperville',
#    'entity': None,
#    'country': 'US',
#    'sources': None,
#    'isMobile': False,
#    'isAnalysis': None,
#    'parameters': [{'id': 2,
#      'unit': 'µg/m³',
#      'count': 38124,
#      'average': 9.860788954635115,
#      'lastValue': 6.8,
#      'parameter': 'pm25',
#      'displayName': 'pm25 µg/m³',
#      'lastUpdated': '2024-03-11T18:00:00+00:00',
#      'parameterId': 2,
#      'firstUpdated': '2017-10-02T23:00:00+00:00',
#      'manufacturers': None}],
#    'sensorType': None,
#    'coordinates': {'latitude': 41.7714, 'longitude': -88.1522},
#    'lastUpdated': '2024-03-11T18:00:00+00:00',
#    'firstUpdated': '2017-10-02T23:00:00+00:00',
#    'measurements': 38124,
#    'bounds': [-88.1522, 41.7714, -88.1522, 41.7714],
#    'manufacturers': [{'modelName': 'Government Monitor',
#      'manufacturerName': 'Unknown Governmental Organization'}]},
#   {'id': 218,
#    'city': 'Chicago-Naperville-Joliet',
#    'name': 'Ogden Dunes',
#    'entity': None,
#    'country': 'US',
#    'sources': None,
#    'isMobile': False,
#    'isAnalysis': None,
#    'parameters': [{'id': 2,
#      'unit': 'µg/m³',
#      'count': 9434,
#      'average': 9.487937743190678,
#      'lastValue': 5.0,
#      'parameter': 'pm25',
#      'displayName': 'pm25 µg/m³',
#      'lastUpdated': '2024-03-10T19:00:00+00:00',
#      'parameterId': 2,
#      'firstUpdated': '2016-03-13T05:00:00+00:00',
#      'manufacturers': None},
#     {'id': 10,
#      'unit': 'ppm',
#      'count': 46517,
#      'average': 0.028136417299119587,
#      'lastValue': 0.043,
#      'parameter': 'o3',
#      'displayName': 'o3 ppm',
#      'lastUpdated': '2024-03-11T18:00:00+00:00',
#      'parameterId': 10,
#      'firstUpdated': '2016-04-02T07:00:00+00:00',
#      'manufacturers': None}],
#    'sensorType': None,
#    'coordinates': {'latitude': 41.617814, 'longitude': -87.199533},
#    'lastUpdated': '2024-03-11T18:00:00+00:00',
#    'firstUpdated': '2016-03-13T05:00:00+00:00',
#    'measurements': 55951,
#    'bounds': [-87.199533, 41.617814, -87.199533, 41.617814],
#    'manufacturers': [{'modelName': 'Government Monitor',
#      'manufacturerName': 'Unknown Governmental Organization'}]},
#   {'id': 8650,
#    'city': 'Chicago-Naperville-Joliet',
#    'name': 'Kingery Near-road #1',
#    'entity': None,
#    'country': 'US',
#    'sources': None,
#    'isMobile': False,
#    'isAnalysis': None,
#    'parameters': [{'id': 2,
#      'unit': 'µg/m³',
#      'count': 34859,
#      'average': 10.59587436964837,
#      'lastValue': 5.5,
#      'parameter': 'pm25',
#      'displayName': 'pm25 µg/m³',
#      'lastUpdated': '2024-03-11T18:00:00+00:00',
#      'parameterId': 2,
#      'firstUpdated': '2019-03-07T17:00:00+00:00',
#      'manufacturers': None}],
#    'sensorType': None,
#    'coordinates': {'latitude': 41.578603, 'longitude': -87.557392},
#    'lastUpdated': '2024-03-11T18:00:00+00:00',
#    'firstUpdated': '2019-03-07T17:00:00+00:00',
#    'measurements': 34859,
#    'bounds': [-87.557392, 41.578603, -87.557392, 41.578603],
#    'manufacturers': [{'modelName': 'Government Monitor',
#      'manufacturerName': 'Unknown Governmental Organization'}]},
#   {'id': 232844,
#    'city': 'Chicago-Naperville-Joliet',
#    'name': 'East Chicago - Marin',
#    'entity': None,
#    'country': 'US',
#    'sources': None,
#    'isMobile': False,
#    'isAnalysis': None,
#    'parameters': [{'id': 9,
#      'unit': 'ppm',
#      'count': 16142,
#      'average': 0.0008499365482233166,
#      'lastValue': 0.0007,
#      'parameter': 'so2',
#      'displayName': 'so2 ppm',
#      'lastUpdated': '2024-03-11T18:00:00+00:00',
#      'parameterId': 9,
#      'firstUpdated': '2021-08-20T12:00:00+00:00',
#      'manufacturers': None},
#     {'id': 2,
#      'unit': 'µg/m³',
#      'count': 17809,
#      'average': 9.59693106704436,
#      'lastValue': 5.9,
#      'parameter': 'pm25',
#      'displayName': 'pm25 µg/m³',
#      'lastUpdated': '2024-03-11T18:00:00+00:00',
#      'parameterId': 2,
#      'firstUpdated': '2021-08-20T12:00:00+00:00',
#      'manufacturers': None}],
#    'sensorType': None,
#    'coordinates': {'latitude': 41.653446, 'longitude': -87.435435},
#    'lastUpdated': '2024-03-11T18:00:00+00:00',
#    'firstUpdated': '2021-08-20T12:00:00+00:00',
#    'measurements': 33951,
#    'bounds': [-87.435435, 41.653446, -87.435435, 41.653446],
#    'manufacturers': [{'modelName': 'Government Monitor',
#      'manufacturerName': 'Unknown Governmental Organization'}]},
#   {'id': 8638,
#    'city': 'Chicago-Naperville-Joliet',
#    'name': 'Joliet',
#    'entity': None,
#    'country': 'US',
#    'sources': None,
#    'isMobile': False,
#    'isAnalysis': None,
#    'parameters': [{'id': 2,
#      'unit': 'µg/m³',
#      'count': 39927,
#      'average': 9.81952775452468,
#      'lastValue': 3.1,
#      'parameter': 'pm25',
#      'displayName': 'pm25 µg/m³',
#      'lastUpdated': '2024-03-09T18:00:00+00:00',
#      'parameterId': 2,
#      'firstUpdated': '2018-01-02T19:00:00+00:00',
#      'manufacturers': None}],
#    'sensorType': None,
#    'coordinates': {'latitude': 41.526885, 'longitude': -88.116474},
#    'lastUpdated': '2024-03-09T18:00:00+00:00',
#    'firstUpdated': '2018-01-02T19:00:00+00:00',
#    'measurements': 39927,
#    'bounds': [-88.116474, 41.526885, -88.116474, 41.526885],
#    'manufacturers': [{'modelName': 'Government Monitor',
#      'manufacturerName': 'Unknown Governmental Organization'}]}]}

# %%
data['results'][0]
# Out:
# {'id': 2047319,
#  'city': 'Chicago-Naperville-Joliet',
#  'name': 'McCook',
#  'entity': None,
#  'country': 'US',
#  'sources': None,
#  'isMobile': False,
#  'isAnalysis': None,
#  'parameters': [{'id': 2,
#    'unit': 'µg/m³',
#    'count': 1432,
#    'average': 6.8,
#    'lastValue': 7.3,
#    'parameter': 'pm25',
#    'displayName': 'pm25 µg/m³',
#    'lastUpdated': '2024-03-11T18:00:00+00:00',
#    'parameterId': 2,
#    'firstUpdated': '2024-01-02T16:00:00+00:00',
#    'manufacturers': None}],
#  'sensorType': None,
#  'coordinates': {'latitude': 41.80117, 'longitude': -87.83194},
#  'lastUpdated': '2024-03-11T18:00:00+00:00',
#  'firstUpdated': '2024-01-02T16:00:00+00:00',
#  'measurements': 1432,
#  'bounds': [-87.83194, 41.80117, -87.83194, 41.80117],
#  'manufacturers': [{'modelName': 'Government Monitor',
#    'manufacturerName': 'Unknown Governmental Organization'}]}

# %%
data
# Out:
# {'meta': {'name': 'openaq-api',
#   'license': '',
#   'website': '/',
#   'page': 1,
#   'limit': 1000,
#   'found': 18},
#  'results': [{'id': 2047319,
#    'city': 'Chicago-Naperville-Joliet',
#    'name': 'McCook',
#    'entity': None,
#    'country': 'US',
#    'sources': None,
#    'isMobile': False,
#    'isAnalysis': None,
#    'parameters': [{'id': 2,
#      'unit': 'µg/m³',
#      'count': 1432,
#      'average': 6.8,
#      'lastValue': 7.3,
#      'parameter': 'pm25',
#      'displayName': 'pm25 µg/m³',
#      'lastUpdated': '2024-03-11T18:00:00+00:00',
#      'parameterId': 2,
#      'firstUpdated': '2024-01-02T16:00:00+00:00',
#      'manufacturers': None}],
#    'sensorType': None,
#    'coordinates': {'latitude': 41.80117, 'longitude': -87.83194},
#    'lastUpdated': '2024-03-11T18:00:00+00:00',
#    'firstUpdated': '2024-01-02T16:00:00+00:00',
#    'measurements': 1432,
#    'bounds': [-87.83194, 41.80117, -87.83194, 41.80117],
#    'manufacturers': [{'modelName': 'Government Monitor',
#      'manufacturerName': 'Unknown Governmental Organization'}]},
#   {'id': 223,
#    'city': 'Chicago-Naperville-Joliet',
#    'name': 'Gary-IITRI',
#    'entity': None,
#    'country': 'US',
#    'sources': None,
#    'isMobile': False,
#    'isAnalysis': None,
#    'parameters': [{'id': 11,
#      'unit': 'µg/m³',
#      'count': 30258,
#      'average': 0.6917327648886192,
#      'lastValue': 0.18,
#      'parameter': 'bc',
#      'displayName': 'bc µg/m³',
#      'lastUpdated': '2021-01-02T00:00:00+00:00',
#      'parameterId': 11,
#      'firstUpdated': '2016-03-06T19:00:00+00:00',
#      'manufacturers': None},
#     {'id': 10,
#      'unit': 'ppm',
#      'count': 44841,
#      'average': 0.027885810454396066,
#      'lastValue': 0.041,
#      'parameter': 'o3',
#      'displayName': 'o3 ppm',
#      'lastUpdated': '2024-03-11T18:00:00+00:00',
#      'parameterId': 10,
#      'firstUpdated': '2016-04-01T07:00:00+00:00',
#      'manufacturers': None},
#     {'id': 1,
#      'unit': 'µg/m³',
#      'count': 51468,
#      'average': 19.168185735832825,
#      'lastValue': 42.0,
#      'parameter': 'pm10',
#      'displayName': 'pm10 µg/m³',
#      'lastUpdated': '2024-03-11T18:00:00+00:00',
#      'parameterId': 1,
#      'firstUpdated': '2016-03-06T19:00:00+00:00',
#      'manufacturers': None},
#     {'id': 2,
#      'unit': 'µg/m³',
#      'count': 9572,
#      'average': 8.862299537917904,
#      'lastValue': 0.5,
#      'parameter': 'pm25',
#      'displayName': 'pm25 µg/m³',
#      'lastUpdated': '2024-03-10T19:00:00+00:00',
#      'parameterId': 2,
#      'firstUpdated': '2016-03-13T05:00:00+00:00',
#      'manufacturers': None},
#     {'id': 9,
#      'unit': 'ppm',
#      'count': 49791,
#      'average': 0.0007170649379680644,
#      'lastValue': 0.0001,
#      'parameter': 'so2',
#      'displayName': 'so2 ppm',
#      'lastUpdated': '2024-03-11T18:00:00+00:00',
#      'parameterId': 9,
#      'firstUpdated': '2016-03-06T19:00:00+00:00',
#      'manufacturers': None},
#     {'id': 7,
#      'unit': 'ppm',
#      'count': 46393,
#      'average': 0.008949742701870322,
#      'lastValue': 0.0007,
#      'parameter': 'no2',
#      'displayName': 'no2 ppm',
#      'lastUpdated': '2024-03-11T18:00:00+00:00',
#      'parameterId': 7,
#      'firstUpdated': '2016-03-06T19:00:00+00:00',
#      'manufacturers': None}],
#    'sensorType': None,
#    'coordinates': {'latitude': 41.606563, 'longitude': -87.305015},
#    'lastUpdated': '2024-03-11T18:00:00+00:00',
#    'firstUpdated': '2016-03-06T19:00:00+00:00',
#    'measurements': 232323,
#    'bounds': [-87.305015, 41.606563, -87.305015, 41.606563],
#    'manufacturers': [{'modelName': 'Government Monitor',
#      'manufacturerName': 'Unknown Governmental Organization'}]},
#   {'id': 424,
#    'city': 'Chicago-Naperville-Joliet',
#    'name': 'CHI_COM',
#    'entity': None,
#    'country': 'US',
#    'sources': None,
#    'isMobile': False,
#    'isAnalysis': None,
#    'parameters': [{'id': 10,
#      'unit': 'ppm',
#      'count': 38446,
#      'average': 0.027506245099136333,
#      'lastValue': 0.041,
#      'parameter': 'o3',
#      'displayName': 'o3 ppm',
#      'lastUpdated': '2024-03-11T18:00:00+00:00',
#      'parameterId': 10,
#      'firstUpdated': '2016-03-06T19:00:00+00:00',
#      'manufacturers': None},
#     {'id': 2,
#      'unit': 'µg/m³',
#      'count': 49120,
#      'average': 9.071560256381174,
#      'lastValue': 5.3,
#      'parameter': 'pm25',
#      'displayName': 'pm25 µg/m³',
#      'lastUpdated': '2024-03-11T18:00:00+00:00',
#      'parameterId': 2,
#      'firstUpdated': '2016-03-06T19:00:00+00:00',
#      'manufacturers': None}],
#    'sensorType': None,
#    'coordinates': {'latitude': 41.7547, 'longitude': -87.7136},
#    'lastUpdated': '2024-03-11T18:00:00+00:00',
#    'firstUpdated': '2016-03-06T19:00:00+00:00',
#    'measurements': 87566,
#    'bounds': [-87.7136, 41.7547, -87.7136, 41.7547],
#    'manufacturers': [{'modelName': 'Government Monitor',
#      'manufacturerName': 'Unknown Governmental Organization'}]},
#   {'id': 1153,
#    'city': 'Chicago-Naperville-Joliet',
#    'name': 'ALSIP',
#    'entity': None,
#    'country': 'US',
#    'sources': None,
#    'isMobile': False,
#    'isAnalysis': None,
#    'parameters': [{'id': 10,
#      'unit': 'ppm',
#      'count': 40762,
#      'average': 0.028271936052167115,
#      'lastValue': 0.04,
#      'parameter': 'o3',
#      'displayName': 'o3 ppm',
#      'lastUpdated': '2024-03-11T18:00:00+00:00',
#      'parameterId': 10,
#      'firstUpdated': '2016-03-06T19:00:00+00:00',
#      'manufacturers': None},
#     {'id': 2,
#      'unit': 'µg/m³',
#      'count': 46839,
#      'average': 9.117925675192474,
#      'lastValue': 7.0,
#      'parameter': 'pm25',
#      'displayName': 'pm25 µg/m³',
#      'lastUpdated': '2024-03-11T18:00:00+00:00',
#      'parameterId': 2,
#      'firstUpdated': '2016-03-06T19:00:00+00:00',
#      'manufacturers': None}],
#    'sensorType': None,
#    'coordinates': {'latitude': 41.6708, 'longitude': -87.7325},
#    'lastUpdated': '2024-03-11T18:00:00+00:00',
#    'firstUpdated': '2016-03-06T19:00:00+00:00',
#    'measurements': 87601,
#    'bounds': [-87.7325, 41.6708, -87.7325, 41.6708],
#    'manufacturers': [{'modelName': 'Government Monitor',
#      'manufacturerName': 'Unknown Governmental Organization'}]},
#   {'id': 1414,
#    'city': 'Chicago-Naperville-Joliet',
#    'name': 'BRAIDWD',
#    'entity': None,
#    'country': 'US',
#    'sources': None,
#    'isMobile': False,
#    'isAnalysis': None,
#    'parameters': [{'id': 2,
#      'unit': 'µg/m³',
#      'count': 50400,
#      'average': 8.516323861873293,
#      'lastValue': 5.3,
#      'parameter': 'pm25',
#      'displayName': 'pm25 µg/m³',
#      'lastUpdated': '2024-03-11T18:00:00+00:00',
#      'parameterId': 2,
#      'firstUpdated': '2016-03-06T19:00:00+00:00',
#      'manufacturers': None},
#     {'id': 10,
#      'unit': 'ppm',
#      'count': 42305,
#      'average': 0.030714307504575218,
#      'lastValue': 0.042,
#      'parameter': 'o3',
#      'displayName': 'o3 ppm',
#      'lastUpdated': '2024-03-11T18:00:00+00:00',
#      'parameterId': 10,
#      'firstUpdated': '2016-03-06T19:00:00+00:00',
#      'manufacturers': None}],
#    'sensorType': None,
#    'coordinates': {'latitude': 41.2222, 'longitude': -88.1906},
#    'lastUpdated': '2024-03-11T18:00:00+00:00',
#    'firstUpdated': '2016-03-06T19:00:00+00:00',
#    'measurements': 92705,
#    'bounds': [-88.1906, 41.2222, -88.1906, 41.2222],
#    'manufacturers': [{'modelName': 'Government Monitor',
#      'manufacturerName': 'Unknown Governmental Organization'}]},
#   {'id': 1621,
#    'city': 'Chicago-Naperville-Joliet',
#    'name': 'CARY',
#    'entity': None,
#    'country': 'US',
#    'sources': None,
#    'isMobile': False,
#    'isAnalysis': None,
#    'parameters': [{'id': 10,
#      'unit': 'ppm',
#      'count': 40094,
#      'average': 0.031798923573734594,
#      'lastValue': 0.04,
#      'parameter': 'o3',
#      'displayName': 'o3 ppm',
#      'lastUpdated': '2024-03-11T18:00:00+00:00',
#      'parameterId': 10,
#      'firstUpdated': '2016-03-06T19:00:00+00:00',
#      'manufacturers': None},
#     {'id': 2,
#      'unit': 'µg/m³',
#      'count': 49927,
#      'average': 8.747162874117269,
#      'lastValue': 5.3,
#      'parameter': 'pm25',
#      'displayName': 'pm25 µg/m³',
#      'lastUpdated': '2024-03-11T18:00:00+00:00',
#      'parameterId': 2,
#      'firstUpdated': '2016-03-06T19:00:00+00:00',
#      'manufacturers': None}],
#    'sensorType': None,
#    'coordinates': {'latitude': 42.2211, 'longitude': -88.2411},
#    'lastUpdated': '2024-03-11T18:00:00+00:00',
#    'firstUpdated': '2016-03-06T19:00:00+00:00',
#    'measurements': 90021,
#    'bounds': [-88.2411, 42.2211, -88.2411, 42.2211],
#    'manufacturers': [{'modelName': 'Government Monitor',
#      'manufacturerName': 'Unknown Governmental Organization'}]},
#   {'id': 1656,
#    'city': 'Chicago-Naperville-Joliet',
#    'name': 'CHIWAUKEE',
#    'entity': None,
#    'country': 'US',
#    'sources': None,
#    'isMobile': False,
#    'isAnalysis': None,
#    'parameters': [{'id': 2,
#      'unit': 'µg/m³',
#      'count': 46492,
#      'average': 7.234893492992632,
#      'lastValue': 4.8,
#      'parameter': 'pm25',
#      'displayName': 'pm25 µg/m³',
#      'lastUpdated': '2024-03-11T18:00:00+00:00',
#      'parameterId': 2,
#      'firstUpdated': '2016-03-06T19:00:00+00:00',
#      'manufacturers': None},
#     {'id': 10,
#      'unit': 'ppm',
#      'count': 30835,
#      'average': 0.03631169244928967,
#      'lastValue': 0.044,
#      'parameter': 'o3',
#      'displayName': 'o3 ppm',
#      'lastUpdated': '2024-03-11T18:00:00+00:00',
#      'parameterId': 10,
#      'firstUpdated': '2016-04-01T15:00:00+00:00',
#      'manufacturers': None}],
#    'sensorType': None,
#    'coordinates': {'latitude': 42.5047, 'longitude': -87.8111},
#    'lastUpdated': '2024-03-11T18:00:00+00:00',
#    'firstUpdated': '2016-03-06T19:00:00+00:00',
#    'measurements': 77327,
#    'bounds': [-87.8111, 42.5047, -87.8111, 42.5047],
#    'manufacturers': [{'modelName': 'Government Monitor',
#      'manufacturerName': 'Unknown Governmental Organization'}]},
#   {'id': 1657,
#    'city': 'Chicago-Naperville-Joliet',
#    'name': 'CHI_SP',
#    'entity': None,
#    'country': 'US',
#    'sources': None,
#    'isMobile': False,
#    'isAnalysis': None,
#    'parameters': [{'id': 2,
#      'unit': 'µg/m³',
#      'count': 32266,
#      'average': 9.100754981033411,
#      'lastValue': 4.4,
#      'parameter': 'pm25',
#      'displayName': 'pm25 µg/m³',
#      'lastUpdated': '2024-03-11T18:00:00+00:00',
#      'parameterId': 2,
#      'firstUpdated': '2016-03-11T15:00:00+00:00',
#      'manufacturers': None}],
#    'sensorType': None,
#    'coordinates': {'latitude': 41.9136, 'longitude': -87.7239},
#    'lastUpdated': '2024-03-11T18:00:00+00:00',
#    'firstUpdated': '2016-03-11T15:00:00+00:00',
#    'measurements': 32266,
#    'bounds': [-87.7239, 41.9136, -87.7239, 41.9136],
#    'manufacturers': [{'modelName': 'Government Monitor',
#      'manufacturerName': 'Unknown Governmental Organization'}]},
#   {'id': 1856,
#    'city': 'Chicago-Naperville-Joliet',
#    'name': 'Cicero Liberty',
#    'entity': None,
#    'country': 'US',
#    'sources': None,
#    'isMobile': False,
#    'isAnalysis': None,
#    'parameters': [{'id': 2,
#      'unit': 'µg/m³',
#      'count': 45473,
#      'average': 9.149802410590773,
#      'lastValue': 8.0,
#      'parameter': 'pm25',
#      'displayName': 'pm25 µg/m³',
#      'lastUpdated': '2024-03-11T18:00:00+00:00',
#      'parameterId': 2,
#      'firstUpdated': '2016-03-06T19:00:00+00:00',
#      'manufacturers': None}],
#    'sensorType': None,
#    'coordinates': {'latitude': 41.864329, 'longitude': -87.748826},
#    'lastUpdated': '2024-03-11T18:00:00+00:00',
#    'firstUpdated': '2016-03-06T19:00:00+00:00',
#    'measurements': 45473,
#    'bounds': [-87.748826, 41.864329, -87.748826, 41.864329],
#    'manufacturers': [{'modelName': 'Government Monitor',
#      'manufacturerName': 'Unknown Governmental Organization'}]},
#   {'id': 1962,
#    'city': 'Chicago-Naperville-Joliet',
#    'name': 'NORTHBRK',
#    'entity': None,
#    'country': 'US',
#    'sources': None,
#    'isMobile': False,
#    'isAnalysis': None,
#    'parameters': [{'id': 10,
#      'unit': 'ppm',
#      'count': 51776,
#      'average': 0.030157617799921627,
#      'lastValue': 0.041,
#      'parameter': 'o3',
#      'displayName': 'o3 ppm',
#      'lastUpdated': '2024-03-11T18:00:00+00:00',
#      'parameterId': 10,
#      'firstUpdated': '2016-03-06T19:00:00+00:00',
#      'manufacturers': None},
#     {'id': 2,
#      'unit': 'µg/m³',
#      'count': 45078,
#      'average': 8.342141367439746,
#      'lastValue': 5.9,
#      'parameter': 'pm25',
#      'displayName': 'pm25 µg/m³',
#      'lastUpdated': '2024-03-11T18:00:00+00:00',
#      'parameterId': 2,
#      'firstUpdated': '2016-07-28T13:00:00+00:00',
#      'manufacturers': None}],
#    'sensorType': None,
#    'coordinates': {'latitude': 42.1406, 'longitude': -87.7994},
#    'lastUpdated': '2024-03-11T18:00:00+00:00',
#    'firstUpdated': '2016-03-06T19:00:00+00:00',
#    'measurements': 96854,
#    'bounds': [-87.7994, 42.1406, -87.7994, 42.1406],
#    'manufacturers': [{'modelName': 'Government Monitor',
#      'manufacturerName': 'Unknown Governmental Organization'}]},
#   {'id': 2085,
#    'city': 'Chicago-Naperville-Joliet',
#    'name': 'SCHILPRK',
#    'entity': None,
#    'country': 'US',
#    'sources': None,
#    'isMobile': False,
#    'isAnalysis': None,
#    'parameters': [{'id': 2,
#      'unit': 'µg/m³',
#      'count': 8441,
#      'average': 10.741591544917624,
#      'lastValue': 6.9,
#      'parameter': 'pm25',
#      'displayName': 'pm25 µg/m³',
#      'lastUpdated': '2024-03-11T18:00:00+00:00',
#      'parameterId': 2,
#      'firstUpdated': '2022-11-15T14:00:00+00:00',
#      'manufacturers': None},
#     {'id': 10,
#      'unit': 'ppm',
#      'count': 42952,
#      'average': 0.024365116513160392,
#      'lastValue': 0.04,
#      'parameter': 'o3',
#      'displayName': 'o3 ppm',
#      'lastUpdated': '2024-03-11T18:00:00+00:00',
#      'parameterId': 10,
#      'firstUpdated': '2016-03-06T19:00:00+00:00',
#      'manufacturers': None}],
#    'sensorType': None,
#    'coordinates': {'latitude': 41.965, 'longitude': -87.8761},
#    'lastUpdated': '2024-03-11T18:00:00+00:00',
#    'firstUpdated': '2016-03-06T19:00:00+00:00',
#    'measurements': 51393,
#    'bounds': [-87.8761, 41.965, -87.8761, 41.965],
#    'manufacturers': [{'modelName': 'Government Monitor',
#      'manufacturerName': 'Unknown Governmental Organization'}]},
#   {'id': 2112,
#    'city': 'Chicago-Naperville-Joliet',
#    'name': 'DESPLNS',
#    'entity': None,
#    'country': 'US',
#    'sources': None,
#    'isMobile': False,
#    'isAnalysis': None,
#    'parameters': [{'id': 2,
#      'unit': 'µg/m³',
#      'count': 41277,
#      'average': 9.523231203944839,
#      'lastValue': 5.7,
#      'parameter': 'pm25',
#      'displayName': 'pm25 µg/m³',
#      'lastUpdated': '2024-03-11T18:00:00+00:00',
#      'parameterId': 2,
#      'firstUpdated': '2016-12-19T14:00:00+00:00',
#      'manufacturers': None},
#     {'id': 10,
#      'unit': 'ppm',
#      'count': 36435,
#      'average': 0.030804829157174654,
#      'lastValue': 0.041,
#      'parameter': 'o3',
#      'displayName': 'o3 ppm',
#      'lastUpdated': '2024-03-11T18:00:00+00:00',
#      'parameterId': 10,
#      'firstUpdated': '2016-03-31T15:00:00+00:00',
#      'manufacturers': None}],
#    'sensorType': None,
#    'coordinates': {'latitude': 42.0603, 'longitude': -87.8631},
#    'lastUpdated': '2024-03-11T18:00:00+00:00',
#    'firstUpdated': '2016-03-31T15:00:00+00:00',
#    'measurements': 77712,
#    'bounds': [-87.8631, 42.0603, -87.8631, 42.0603],
#    'manufacturers': [{'modelName': 'Government Monitor',
#      'manufacturerName': 'Unknown Governmental Organization'}]},
#   {'id': 7405,
#    'city': 'Chicago-Naperville-Joliet',
#    'name': 'Hammond-167th St',
#    'entity': None,
#    'country': 'US',
#    'sources': None,
#    'isMobile': False,
#    'isAnalysis': None,
#    'parameters': [{'id': 2,
#      'unit': 'µg/m³',
#      'count': 30271,
#      'average': 9.516142416818145,
#      'lastValue': 4.7,
#      'parameter': 'pm25',
#      'displayName': 'pm25 µg/m³',
#      'lastUpdated': '2024-03-11T18:00:00+00:00',
#      'parameterId': 2,
#      'firstUpdated': '2019-08-16T13:00:00+00:00',
#      'manufacturers': None}],
#    'sensorType': None,
#    'coordinates': {'latitude': 41.594427, 'longitude': -87.495044},
#    'lastUpdated': '2024-03-11T18:00:00+00:00',
#    'firstUpdated': '2019-08-16T13:00:00+00:00',
#    'measurements': 30271,
#    'bounds': [-87.495044, 41.594427, -87.495044, 41.594427],
#    'manufacturers': [{'modelName': 'Government Monitor',
#      'manufacturerName': 'Unknown Governmental Organization'}]},
#   {'id': 8555,
#    'city': 'Chicago-Naperville-Joliet',
#    'name': 'Naperville',
#    'entity': None,
#    'country': 'US',
#    'sources': None,
#    'isMobile': False,
#    'isAnalysis': None,
#    'parameters': [{'id': 2,
#      'unit': 'µg/m³',
#      'count': 38124,
#      'average': 9.860788954635115,
#      'lastValue': 6.8,
#      'parameter': 'pm25',
#      'displayName': 'pm25 µg/m³',
#      'lastUpdated': '2024-03-11T18:00:00+00:00',
#      'parameterId': 2,
#      'firstUpdated': '2017-10-02T23:00:00+00:00',
#      'manufacturers': None}],
#    'sensorType': None,
#    'coordinates': {'latitude': 41.7714, 'longitude': -88.1522},
#    'lastUpdated': '2024-03-11T18:00:00+00:00',
#    'firstUpdated': '2017-10-02T23:00:00+00:00',
#    'measurements': 38124,
#    'bounds': [-88.1522, 41.7714, -88.1522, 41.7714],
#    'manufacturers': [{'modelName': 'Government Monitor',
#      'manufacturerName': 'Unknown Governmental Organization'}]},
#   {'id': 218,
#    'city': 'Chicago-Naperville-Joliet',
#    'name': 'Ogden Dunes',
#    'entity': None,
#    'country': 'US',
#    'sources': None,
#    'isMobile': False,
#    'isAnalysis': None,
#    'parameters': [{'id': 2,
#      'unit': 'µg/m³',
#      'count': 9434,
#      'average': 9.487937743190678,
#      'lastValue': 5.0,
#      'parameter': 'pm25',
#      'displayName': 'pm25 µg/m³',
#      'lastUpdated': '2024-03-10T19:00:00+00:00',
#      'parameterId': 2,
#      'firstUpdated': '2016-03-13T05:00:00+00:00',
#      'manufacturers': None},
#     {'id': 10,
#      'unit': 'ppm',
#      'count': 46517,
#      'average': 0.028136417299119587,
#      'lastValue': 0.043,
#      'parameter': 'o3',
#      'displayName': 'o3 ppm',
#      'lastUpdated': '2024-03-11T18:00:00+00:00',
#      'parameterId': 10,
#      'firstUpdated': '2016-04-02T07:00:00+00:00',
#      'manufacturers': None}],
#    'sensorType': None,
#    'coordinates': {'latitude': 41.617814, 'longitude': -87.199533},
#    'lastUpdated': '2024-03-11T18:00:00+00:00',
#    'firstUpdated': '2016-03-13T05:00:00+00:00',
#    'measurements': 55951,
#    'bounds': [-87.199533, 41.617814, -87.199533, 41.617814],
#    'manufacturers': [{'modelName': 'Government Monitor',
#      'manufacturerName': 'Unknown Governmental Organization'}]},
#   {'id': 8650,
#    'city': 'Chicago-Naperville-Joliet',
#    'name': 'Kingery Near-road #1',
#    'entity': None,
#    'country': 'US',
#    'sources': None,
#    'isMobile': False,
#    'isAnalysis': None,
#    'parameters': [{'id': 2,
#      'unit': 'µg/m³',
#      'count': 34859,
#      'average': 10.59587436964837,
#      'lastValue': 5.5,
#      'parameter': 'pm25',
#      'displayName': 'pm25 µg/m³',
#      'lastUpdated': '2024-03-11T18:00:00+00:00',
#      'parameterId': 2,
#      'firstUpdated': '2019-03-07T17:00:00+00:00',
#      'manufacturers': None}],
#    'sensorType': None,
#    'coordinates': {'latitude': 41.578603, 'longitude': -87.557392},
#    'lastUpdated': '2024-03-11T18:00:00+00:00',
#    'firstUpdated': '2019-03-07T17:00:00+00:00',
#    'measurements': 34859,
#    'bounds': [-87.557392, 41.578603, -87.557392, 41.578603],
#    'manufacturers': [{'modelName': 'Government Monitor',
#      'manufacturerName': 'Unknown Governmental Organization'}]},
#   {'id': 232844,
#    'city': 'Chicago-Naperville-Joliet',
#    'name': 'East Chicago - Marin',
#    'entity': None,
#    'country': 'US',
#    'sources': None,
#    'isMobile': False,
#    'isAnalysis': None,
#    'parameters': [{'id': 2,
#      'unit': 'µg/m³',
#      'count': 17809,
#      'average': 9.59693106704436,
#      'lastValue': 5.9,
#      'parameter': 'pm25',
#      'displayName': 'pm25 µg/m³',
#      'lastUpdated': '2024-03-11T18:00:00+00:00',
#      'parameterId': 2,
#      'firstUpdated': '2021-08-20T12:00:00+00:00',
#      'manufacturers': None},
#     {'id': 9,
#      'unit': 'ppm',
#      'count': 16142,
#      'average': 0.0008499365482233166,
#      'lastValue': 0.0007,
#      'parameter': 'so2',
#      'displayName': 'so2 ppm',
#      'lastUpdated': '2024-03-11T18:00:00+00:00',
#      'parameterId': 9,
#      'firstUpdated': '2021-08-20T12:00:00+00:00',
#      'manufacturers': None}],
#    'sensorType': None,
#    'coordinates': {'latitude': 41.653446, 'longitude': -87.435435},
#    'lastUpdated': '2024-03-11T18:00:00+00:00',
#    'firstUpdated': '2021-08-20T12:00:00+00:00',
#    'measurements': 33951,
#    'bounds': [-87.435435, 41.653446, -87.435435, 41.653446],
#    'manufacturers': [{'modelName': 'Government Monitor',
#      'manufacturerName': 'Unknown Governmental Organization'}]},
#   {'id': 8638,
#    'city': 'Chicago-Naperville-Joliet',
#    'name': 'Joliet',
#    'entity': None,
#    'country': 'US',
#    'sources': None,
#    'isMobile': False,
#    'isAnalysis': None,
#    'parameters': [{'id': 2,
#      'unit': 'µg/m³',
#      'count': 39927,
#      'average': 9.81952775452468,
#      'lastValue': 3.1,
#      'parameter': 'pm25',
#      'displayName': 'pm25 µg/m³',
#      'lastUpdated': '2024-03-09T18:00:00+00:00',
#      'parameterId': 2,
#      'firstUpdated': '2018-01-02T19:00:00+00:00',
#      'manufacturers': None}],
#    'sensorType': None,
#    'coordinates': {'latitude': 41.526885, 'longitude': -88.116474},
#    'lastUpdated': '2024-03-09T18:00:00+00:00',
#    'firstUpdated': '2018-01-02T19:00:00+00:00',
#    'measurements': 39927,
#    'bounds': [-88.116474, 41.526885, -88.116474, 41.526885],
#    'manufacturers': [{'modelName': 'Government Monitor',
#      'manufacturerName': 'Unknown Governmental Organization'}]}]}

# %%
for site in data['results']:
    print(site['name'], site['coordinates']['latitude'], site['coordinates']['longitude'])
    for obs in site['parameters']:
            print(obs['parameter'], obs['lastValue'], obs['lastUpdated'])
    print(site['manufacturers'][0]['modelName'])
    print('\n')
# Out:
# McCook 41.80117 -87.83194
# pm25 7.3 2024-03-11T18:00:00+00:00
# Government Monitor
#
#
# Gary-IITRI 41.606563 -87.305015
# bc 0.18 2021-01-02T00:00:00+00:00
# o3 0.041 2024-03-11T18:00:00+00:00
# pm10 42.0 2024-03-11T18:00:00+00:00
# pm25 0.5 2024-03-10T19:00:00+00:00
# so2 0.0001 2024-03-11T18:00:00+00:00
# no2 0.0007 2024-03-11T18:00:00+00:00
# Government Monitor
#
#
# CHI_COM 41.7547 -87.7136
# o3 0.041 2024-03-11T18:00:00+00:00
# pm25 5.3 2024-03-11T18:00:00+00:00
# Government Monitor
#
#
# ALSIP 41.6708 -87.7325
# o3 0.04 2024-03-11T18:00:00+00:00
# pm25 7.0 2024-03-11T18:00:00+00:00
# Government Monitor
#
#
# BRAIDWD 41.2222 -88.1906
# pm25 5.3 2024-03-11T18:00:00+00:00
# o3 0.042 2024-03-11T18:00:00+00:00
# Government Monitor
#
#
# CARY 42.2211 -88.2411
# o3 0.04 2024-03-11T18:00:00+00:00
# pm25 5.3 2024-03-11T18:00:00+00:00
# Government Monitor
#
#
# CHIWAUKEE 42.5047 -87.8111
# pm25 4.8 2024-03-11T18:00:00+00:00
# o3 0.044 2024-03-11T18:00:00+00:00
# Government Monitor
#
#
# CHI_SP 41.9136 -87.7239
# pm25 4.4 2024-03-11T18:00:00+00:00
# Government Monitor
#
#
# Cicero Liberty 41.864329 -87.748826
# pm25 8.0 2024-03-11T18:00:00+00:00
# Government Monitor
#
#
# NORTHBRK 42.1406 -87.7994
# o3 0.041 2024-03-11T18:00:00+00:00
# pm25 5.9 2024-03-11T18:00:00+00:00
# Government Monitor
#
#
# SCHILPRK 41.965 -87.8761
# pm25 6.9 2024-03-11T18:00:00+00:00
# o3 0.04 2024-03-11T18:00:00+00:00
# Government Monitor
#
#
# DESPLNS 42.0603 -87.8631
# pm25 5.7 2024-03-11T18:00:00+00:00
# o3 0.041 2024-03-11T18:00:00+00:00
# Government Monitor
#
#
# Hammond-167th St 41.594427 -87.495044
# pm25 4.7 2024-03-11T18:00:00+00:00
# Government Monitor
#
#
# Naperville 41.7714 -88.1522
# pm25 6.8 2024-03-11T18:00:00+00:00
# Government Monitor
#
#
# Ogden Dunes 41.617814 -87.199533
# pm25 5.0 2024-03-10T19:00:00+00:00
# o3 0.043 2024-03-11T18:00:00+00:00
# Government Monitor
#
#
# Kingery Near-road #1 41.578603 -87.557392
# pm25 5.5 2024-03-11T18:00:00+00:00
# Government Monitor
#
#
# East Chicago - Marin 41.653446 -87.435435
# pm25 5.9 2024-03-11T18:00:00+00:00
# so2 0.0007 2024-03-11T18:00:00+00:00
# Government Monitor
#
#
# Joliet 41.526885 -88.116474
# pm25 3.1 2024-03-09T18:00:00+00:00
# Government Monitor

# %%
import xyzservices.providers as xyz
from bokeh.plotting import figure, show
from bokeh.models import ColumnDataSource
from bokeh.transform import factor_cmap, factor_mark
from bokeh.transform import linear_cmap, log_cmap
from bokeh.layouts import row

import numpy as np
import math

# %%
# helper function for coordinate conversion between lat/lon in decimal degrees to web mercator
def lnglat_to_meters(longitude: float, latitude: float) -> tuple[float, float]:
    """ Projects the given (longitude, latitude) values into Web Mercator
    coordinates (meters East of Greenwich and meters North of the Equator).

    """
    origin_shift = np.pi * 6378137
    easting = longitude * origin_shift / 180.0
    northing = np.log(np.tan((90 + latitude) * np.pi / 360.0)) * origin_shift / np.pi
    return (easting, northing)

# %%
# Create a dictionary of lat/lons
pm25 = {'parm':[], 'name':[], 'lat':[], 'lon':[], 'avg':[], 'lastValue':[], 'lastUpdated':[], 'units':[], 'x':[], 'y':[], 'type':[]}
ozone = {'parm':[], 'name':[], 'lat':[], 'lon':[], 'avg':[], 'lastValue':[], 'lastUpdated':[], 'units':[], 'x':[], 'y':[], 'type':[]}
so2 = {'parm':[], 'name':[], 'lat':[], 'lon':[], 'avg':[], 'lastValue':[], 'lastUpdated':[], 'units':[], 'x':[], 'y':[], 'type':[]}

# %%
for site in data['results']:
    for obs in site['parameters']:
        if obs['parameter'] == 'pm25':
            pm25['parm'].append(obs['parameter'])
            pm25['name'].append(site['name'])
            pm25['avg'].append(obs['average'])
            pm25['lastValue'].append(obs['lastValue'])
            pm25['lastUpdated'].append(obs['lastUpdated'])
            pm25['units'].append(obs['unit'])
            coords = lnglat_to_meters(site['coordinates']['longitude'], 
                                      site['coordinates']['latitude'])
            pm25['lon'].append(site['coordinates']['longitude'])
            pm25['x'].append(coords[0])
            pm25['lat'].append(site['coordinates']['latitude'])
            pm25['y'].append(coords[1])
            if "N/A" not in site['manufacturers'][0]['modelName']:
                pm25['type'].append(site['manufacturers'][0]['modelName'])
            else:
                pm25['type'].append('Unknown')
        elif obs['parameter'] == 'o3':
            ozone['parm'].append(obs['parameter'])
            ozone['name'].append(site['name'])
            ozone['avg'].append(obs['average'])
            ozone['lastValue'].append(obs['lastValue'])
            ozone['lastUpdated'].append(obs['lastUpdated'])
            ozone['units'].append(obs['unit'])
            coords = lnglat_to_meters(site['coordinates']['longitude'], 
                                      site['coordinates']['latitude'])
            ozone['lon'].append(site['coordinates']['longitude'])
            ozone['lat'].append(site['coordinates']['latitude'])
            ozone['x'].append(coords[0])
            ozone['y'].append(coords[1])
            ozone['type'].append(site['manufacturers'][0]['modelName'])
        elif obs['parameter'] == 'so2':
            so2['parm'].append(obs['parameter'])
            so2['name'].append(site['name'])
            so2['avg'].append(obs['average'])
            so2['lastValue'].append(obs['lastValue'])
            so2['lastUpdated'].append(obs['lastUpdated'])
            so2['units'].append(obs['unit'])
            coords = lnglat_to_meters(site['coordinates']['longitude'], 
                                      site['coordinates']['latitude'])
            so2['lon'].append(site['coordinates']['longitude'])
            so2['lat'].append(site['coordinates']['latitude'])
            so2['type'].append(site['manufacturers'][0]['modelName'])
        else:
            print('Not Supported Yet: ', obs)
            #print('Not Supported Yet')
    #print(site['coordinates']['latitude'], site['coordinates']['longitude'])
# Out:
# Not Supported Yet:  {'id': 11, 'unit': 'µg/m³', 'count': 30258, 'average': 0.6917327648886192, 'lastValue': 0.18, 'parameter': 'bc', 'displayName': 'bc µg/m³', 'lastUpdated': '2021-01-02T00:00:00+00:00', 'parameterId': 11, 'firstUpdated': '2016-03-06T19:00:00+00:00', 'manufacturers': None}
# Not Supported Yet:  {'id': 1, 'unit': 'µg/m³', 'count': 51468, 'average': 19.168185735832825, 'lastValue': 42.0, 'parameter': 'pm10', 'displayName': 'pm10 µg/m³', 'lastUpdated': '2024-03-11T18:00:00+00:00', 'parameterId': 1, 'firstUpdated': '2016-03-06T19:00:00+00:00', 'manufacturers': None}
# Not Supported Yet:  {'id': 7, 'unit': 'ppm', 'count': 46393, 'average': 0.008949742701870322, 'lastValue': 0.0007, 'parameter': 'no2', 'displayName': 'no2 ppm', 'lastUpdated': '2024-03-11T18:00:00+00:00', 'parameterId': 7, 'firstUpdated': '2016-03-06T19:00:00+00:00', 'manufacturers': None}

# %%
def make_plot(ndata, mapper, palette):
    # let's center on UIC
    chi_lat = 41.86937
    chi_lon = -87.64638

    MARKERS = ['hex', 'circle_x', 'triangle']
    TOOLS="hover,crosshair,pan,wheel_zoom,zoom_in,zoom_out,box_zoom,examine,help"

    TOOLTIPS = [
        ("index", "$index"),
        ("(x,y)", "($x, $y)"),
        ("(Lon, Lat)", "@lon, @lat"),
        ("Last Value:", "@lastValue"),
        ("Average Value:", "@avg"),
        ("Last Updated", "@lastUpdated"),
        ("Units", "@units")
    ]
    
    PLOT_HEIGHT = 600
    PLOT_WIDTH = 800
    COLOR_BAR_HEIGHT = PLOT_HEIGHT - 11
    COLOR_BAR_WIDTH = 60
    
    EN = lnglat_to_meters(chi_lon, chi_lat)
    dE = 47500 # (m) easting plus-and-minus from map center
    dN = 47500 # (m) northing plus-and-minus from map center

    x_range = (EN[0] - dE, EN[0] + dE) # (m) Easting x_low, x_high
    y_range = (EN[1] - dN, EN[1] + dN) # (m) Northing y_low, y_high

    TITLE = "CROCUS U-IFL Domain - " + str(ndata['parm'][0])
    
    plot = figure(x_range=x_range, 
                  y_range=y_range,
                  x_axis_type="mercator",
                  y_axis_type="mercator",
                  height=PLOT_HEIGHT,
                  width=PLOT_WIDTH,
                  toolbar_location='below',
                  tools=TOOLS,
                  title=TITLE,
                  tooltips=TOOLTIPS
                  )

    plot.xaxis.axis_label = 'Longitude [Degrees]'
    plot.yaxis.axis_label = 'Latitude [Degrees]'

    plot.add_tile("CartoDB Positron", retina=True)

    # Add the data sources to plot
    source = ColumnDataSource(data=ndata)

    TYPE = sorted(np.unique(np.array(source.data['type'])))
    
    # use the field name of the column source
    cmap = mapper(field_name="lastValue", 
                  palette=palette, 
                  low=0,
                  high=10,
                 )
    
    r = plot.scatter('x', 
                     'y', 
                     alpha=0.8, 
                     color=cmap, 
                     size=15, 
                     source=source,
                     legend_group="type",
                     marker=factor_mark('type', MARKERS, TYPE)
                    )

    # create a color bar from the scatter glyph renderer
    color_bar = r.construct_color_bar(width=10)

    # add colorbar title
    color_bar_plot = figure(title=ndata['units'][0],
                            title_location='right',
                            height=COLOR_BAR_HEIGHT,
                            width=COLOR_BAR_WIDTH,
                            toolbar_location=None,
                            min_border=0,
                            outline_line_color=None
                           )
    color_bar_plot.add_layout(color_bar, 'right')
    color_bar_plot.title.align='center'
    color_bar_plot.title.text_font_size = '14pt'
    color_bar_plot.xaxis.major_label_orientation=0

    plot.legend.location = "top_right"
    plot.legend.title = "Observations"
    
    layout = row(plot, color_bar_plot)

    #return plot
    return layout

# %%
p1 = make_plot(pm25, linear_cmap, "Viridis256")
show(p1)
# Out:
# WARNING:bokeh.core.validation.check:W-1000 (MISSING_RENDERERS): Plot has no renderers: figure(id='p1060', ...)

# %%
p2 = make_plot(ozone, linear_cmap, "Viridis256")
show(p2)
# Out:
# WARNING:bokeh.core.validation.check:W-1000 (MISSING_RENDERERS): Plot has no renderers: figure(id='p1154', ...)

# %%
p3 = make_plot(so2, linear_cmap, "Viridis256")
show(p3)
# Out:
# BokehUserWarning: ColumnDataSource's columns must be of the same length. Current lengths: ('avg', 2), ('lastUpdated', 2), ('lastValue', 2), ('lat', 2), ('lon', 2), ('name', 2), ('parm', 2), ('type', 2), ('units', 2), ('x', 0), ('y', 0)
# WARNING:bokeh.core.validation.check:W-1000 (MISSING_RENDERERS): Plot has no renderers: figure(id='p1248', ...)

# %%
so2
# Out:
# {'parm': ['so2', 'so2'],
#  'name': ['Gary-IITRI', 'East Chicago - Marin'],
#  'lat': [41.606563, 41.653446],
#  'lon': [-87.305015, -87.435435],
#  'avg': [0.0007170649379680644, 0.0008499365482233166],
#  'lastValue': [0.0001, 0.0007],
#  'lastUpdated': ['2024-03-11T18:00:00+00:00', '2024-03-11T18:00:00+00:00'],
#  'units': ['ppm', 'ppm'],
#  'x': [],
#  'y': [],
#  'type': ['Government Monitor', 'Government Monitor']}
